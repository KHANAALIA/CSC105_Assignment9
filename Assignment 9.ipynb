# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("data/healthcare_data.csv")

df
# Out:
#     Patient_ID          Patient_Name  Age  Gender Blood_Type      Diagnosis  \
# 0         1001            John Smith   45    Male         A+   Hypertension
# 1         1002              Jane Doe   62  Female         B-       Diabetes
# 2         1003        Robert Johnson   35    Male         O+         Cancer
# 3         1004          Susan Wilson   78  Female         A-  Heart Disease
# 4         1005         Michael Brown   55    Male        AB+         Asthma
# 5         1006           Lisa Miller   30  Female         B+   Hypertension
# 6         1007           James Davis   48    Male         O-       Diabetes
# 7         1008          Karen Harris   65  Female        AB-         Cancer
# 8         1009          David Wilson   72    Male         A+  Heart Disease
# 9         1010           Linda Smith   42  Female         O+         Asthma
# 10        1011           William Lee   33    Male        AB+   Hypertension
# ...

# %%
Ages=[45,62,35,78,55,51,44,62,29,40,67,49,38,54,58,41,47,35,60,53,49,56,44,65,30,70,35,52,57,43,62,41,46,51,55,42,59,64,40,39,34]
Patients =  50
plt.hist(Ages,Patients,color='blue' ,histtype='bar',rwidth=1.0)
plt.xlabel('Ages')
plt.ylabel('Patients')
plt.title('Patient Ages')
plt.show()

# %%
(df['Gender'] == "Male").sum()/50*100
# Out:
# 50.0

# %% [markdown]
# 50% of patients have cancer

# %%
(df['Diagnosis'] == "Cancer").sum()
# Out:
# 10

# %% [markdown]
# 10 patients have been diagnosed with cancer

# %%
df.query('Age >= 60').sum()
# Out:
# Patient_ID                                                    12248
# Patient_Name      Jane DoeSusan WilsonKaren HarrisDavid WilsonMa...
# Age                                                             797
# Gender            FemaleFemaleFemaleMaleFemaleFemaleMaleMaleFema...
# Blood_Type                               B-A-AB-A+B-A+AB+A-B+A-O-O-
# Diagnosis         DiabetesHeart DiseaseCancerHeart DiseaseCancer...
# Treatment_Cost                                             18756.75
# dtype: object

# %% [markdown]
# average treatment cost is 18756.75

# %%
df.groupby(['Blood_Type']).sum()
# Out:
# C:\Users\aalia\AppData\Local\Temp\ipykernel_33876\1489469572.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['Blood_Type']).sum()
#             Patient_ID  Age  Treatment_Cost
# Blood_Type
# A+                8204  430        25161.50
# A-                6143  350         7351.50
# AB+               7176  334         8930.75
# AB-               5142  246         5771.50
# B+                5124  221         1720.50
# B-                5120  283         1721.50
# O+                8202  347        17220.75
# O-                6164  288         9676.25

# %%
df.Treatment_Cost.sum()/8
# Out:
# 9694.28125

# %% [markdown]
# average treatment cost is 9694.28125

# %% [markdown]
# Blood type A+ has the highest bloodtype cost

# %%
df.groupby(['Gender' , 'Diagnosis'])['Age'].mean()
# Out:
# Gender  Diagnosis
# Female  Asthma           47.666667
#         Cancer           55.333333
#         Diabetes         54.400000
#         Heart Disease    57.750000
#         Hypertension     45.250000
# Male    Asthma           49.000000
#         Cancer           44.500000
#         Diabetes         52.000000
#         Heart Disease    54.666667
#         Hypertension     39.166667
# Name: Age, dtype: float64
